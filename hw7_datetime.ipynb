# %%
from datetime import datetime

# %% [markdown]
# ### Задание 1

# %%
newspapers = ['The Moscow Times - Wednesday, October 2, 2002',
'The Guardian - Friday, 11.10.13',
'Daily News - Thursday, 18 August 1977']
for newspaper in newspapers:
    if newspaper.split(' ')[1] == 'Moscow':
        print(datetime.strptime(''.join(newspaper.split(' ')[4:]),'%A,%B%d,%Y'))
    elif newspaper.split(' ')[1] == 'Guardian':
        print(datetime.strptime(''.join(newspaper.split(' ')[3:]),'%A,%d.%m.%y'))
    elif newspaper.split(' ')[1] == 'News':
        print(datetime.strptime(''.join(newspaper.split(' ')[3:]),'%A,%d%B%Y'))
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00

# %% [markdown]
# ### Задание 2

# %%
stream = ['2018-04-02', '2018-02-29', '2018-19-02']
stream_tested = []
for date in stream:
    try:
        datetime.strptime(date,'%Y-%m-%d')
        stream_tested.append(True)
    except:
        stream_tested.append(False)
list(zip(stream,stream_tested))
# Out:
# [('2018-04-02', True), ('2018-02-29', False), ('2018-19-02', False)]

# %% [markdown]
# ### Задание 3

# %%
from datetime import timedelta

# %%
def date_range (start_date,end_date):
    date_list = []
    try:
        start_date_datetime = datetime.strptime(start_date,'%Y-%m-%d')
        end_date_datetime = datetime.strptime(end_date,'%Y-%m-%d')
        current_date = datetime.strptime(start_date,'%Y-%m-%d')
        if start_date_datetime > end_date_datetime:
            print('start date > end date')
            return []
        while current_date != end_date_datetime:
            date_list.append(datetime.strftime(current_date,'%Y-%m-%d'))
            current_date = current_date + timedelta(days=1)
    except ValueError:
        print('Wrong date format')
        return []       
    return(date_list)

date_range(input('Input start date: '),input('Input end date: '))
# Out:
# Input start date: 2012-02-14
# Input end date: 2013-02-14
# ['2012-02-14',
#  '2012-02-15',
#  '2012-02-16',
#  '2012-02-17',
#  '2012-02-18',
#  '2012-02-19',
#  '2012-02-20',
#  '2012-02-21',
#  '2012-02-22',
#  '2012-02-23',
#  '2012-02-24',
#  '2012-02-25',
#  '2012-02-26',
#  '2012-02-27',
#  '2012-02-28',
#  '2012-02-29',
#  '2012-03-01',
#  '2012-03-02',
#  '2012-03-03',
#  '2012-03-04',
#  '2012-03-05',
#  '2012-03-06',
#  '2012-03-07',
#  '2012-03-08',
#  '2012-03-09',
#  '2012-03-10',
#  '2012-03-11',
#  '2012-03-12',
#  '2012-03-13',
#  '2012-03-14',
#  '2012-03-15',
#  '2012-03-16',
#  '2012-03-17',
#  '2012-03-18',
#  '2012-03-19',
#  '2012-03-20',
#  '2012-03-21',
#  '2012-03-22',
#  '2012-03-23',
#  '2012-03-24',
#  '2012-03-25',
#  '2012-03-26',
#  '2012-03-27',
#  '2012-07-30',
#  '2012-07-31',
#  '2012-08-01',
#  '2012-08-02',
#  '2012-08-03',
#  '2012-08-04',
#  '2012-08-05',
#  '2012-08-06',
#  '2012-08-07',
#  '2012-08-08',
#  '2012-08-09',
#  '2012-08-10',
#  '2012-08-11',
#  '2012-08-12',
#  '2012-08-13',
#  '2012-08-14',
#  '2012-08-15',
#  '2012-08-16',
#  '2012-08-17',
#  '2012-08-18',
#  '2012-08-19',
#  '2012-08-20',
#  '2012-08-21',
#  '2012-08-22',
#  '2012-08-23',
#  '2012-08-24',
#  '2012-08-25',
#  '2012-08-26',
#  '2012-08-27',
#  '2012-08-28',
#  '2012-08-29',
#  '2012-08-30',
#  '2012-08-31',
#  '2012-09-01',
#  '2012-09-02',
#  '2012-09-03',
#  '2012-09-04',
#  '2012-09-05',
#  '2012-09-06',
#  '2012-09-07',
#  '2012-09-08',
#  '2012-09-09',
#  '2012-09-10',
#  '2012-09-11',
#  '2012-09-12',
#  '2012-09-13',
#  '2012-09-14',
#  '2012-09-15',
#  '2012-09-16',
#  '2012-09-17',
#  '2012-09-18',
#  '2012-09-19',
#  '2012-09-20',
#  '2012-09-21',
#  '2012-09-22',
#  '2012-09-23',
#  '2012-09-24',
#  '2012-09-25',
#  '2012-09-26',
#  '2012-09-27',
#  '2012-09-28',
#  '2012-09-29',
#  '2012-09-30',
#  '2012-10-01',
#  '2012-10-02',
#  '2012-10-03',
#  '2012-10-04',
#  '2012-10-05',
#  '2012-10-06',
#  '2012-10-07',
#  '2012-10-08',
#  '2012-10-09',
#  '2012-10-10',
#  '2012-10-11',
#  '2012-10-12',
#  '2012-10-13',
#  '2012-10-14',
#  '2012-10-15',
#  '2012-10-16',
#  '2012-10-17',
#  '2012-10-18',
#  '2012-10-19',
#  '2012-10-20',
#  '2012-10-21',
#  '2012-10-22',
#  '2012-10-23',
#  '2012-10-24',
#  '2012-10-25',
#  '2012-10-26',
#  '2012-10-27',
#  '2012-10-28',
#  '2012-10-29',
#  '2012-10-30',
#  '2012-10-31',
#  '2012-11-01',
#  '2012-11-02',
#  '2012-11-03',
#  '2012-11-04',
#  '2012-11-05',
#  '2012-11-06',
#  '2012-11-07',
#  '2012-11-08',
#  '2012-11-09',
#  '2012-11-10',
#  '2012-11-11',
#  '2012-11-12',
#  '2012-11-13',
#  '2012-11-14',
#  '2012-11-15',
#  '2012-11-16',
#  '2012-11-17',
#  '2012-11-18',
#  '2012-11-19',
#  '2012-11-20',
#  '2012-11-21',
#  '2012-11-22',
#  '2012-11-23',
#  '2012-11-24',
#  '2012-11-25',
#  '2012-11-26',
#  '2012-11-27',
#  '2012-11-28',
#  '2012-11-29',
#  '2012-11-30',
#  '2012-12-01',
#  '2012-12-02',
#  '2012-12-03',
#  '2012-12-04',
#  '2012-12-05',
#  '2012-12-06',
#  '2012-12-07',
#  '2012-12-08',
#  '2012-12-09',
#  '2012-12-10',
#  '2012-12-11',
#  '2012-12-12',
#  '2012-12-13',
#  '2012-12-14',
#  '2012-12-15',
#  '2012-12-16',
#  '2012-12-17',
#  '2012-12-18',
#  '2012-12-19',
#  '2012-12-20',
#  '2012-12-21',
#  '2012-12-22',
#  '2012-12-23',
#  '2012-12-24',
#  '2012-12-25',
#  '2012-12-26',
#  '2012-12-27',
#  '2012-12-28',
#  '2012-12-29',
#  '2012-12-30',
#  '2012-12-31',
#  '2013-01-01',
#  '2013-01-02',
#  '2013-01-03',
#  '2013-01-04',
#  '2013-01-05',
#  '2013-01-06',
#  '2013-01-07',
#  '2013-01-08',
#  '2013-01-09',
#  '2013-01-10',
#  '2013-01-11',
#  '2013-01-12',
#  '2013-01-13',
#  '2013-01-14',
#  '2013-01-15',
#  '2013-01-16',
#  '2013-01-17',
#  '2013-01-18',
#  '2013-01-19',
#  '2013-01-20',
#  '2013-01-21',
#  '2013-01-22',
#  '2013-01-23',
#  '2013-01-24',
#  '2013-01-25',
#  '2013-01-26',
#  '2013-01-27',
#  '2013-01-28',
#  '2013-01-29',
#  '2013-01-30',
#  '2013-01-31',
#  '2013-02-01',
#  '2013-02-02',
#  '2013-02-03',
#  '2013-02-04',
#  '2013-02-05',
#  '2013-02-06',
#  '2013-02-07',
#  '2013-02-08',
#  '2013-02-09',
#  '2013-02-10',
#  '2013-02-11',
#  '2013-02-12',
#  '2013-02-13']

# %% [markdown]
# ### Задание 4

# %%
DEFAULT_USER_COUNT = 3

def delete_and_return_last_user(region, default_list=['A100', 'A101', 'A102']):
    element_to_delete = default_list[-1]
    print(default_list)
    default_list.remove(element_to_delete) #При повторном вызове функции, после этой строки default_list=['A100'], 
        # в нём нет элемента с индексом 1, чтобы работало корректно нужно заменить default_list[DEFAULT_USER_COUNT-2]
        # на default_list[-1]
    return default_list[DEFAULT_USER_COUNT-2]

print(delete_and_return_last_user(1))
print(delete_and_return_last_user(1))
# Out:
# ['A100', 'A101', 'A102']
# A101
# ['A100', 'A101']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-60cbe13a14df> in <module>
#      10
#      11 print(delete_and_return_last_user(1))
# ---> 12 print(delete_and_return_last_user(1))
#
# <ipython-input-6-60cbe13a14df> in delete_and_return_last_user(region, default_list)
#       7         # в нём нет элемента с индексом 1, чтобы работало корректно нужно заменить default_list[DEFAULT_USER_COUNT-2]
#       8         # на default_list[-1]
# ----> 9     return default_list[DEFAULT_USER_COUNT-2]
#      10
#      11 print(delete_and_return_last_user(1))
#
# IndexError: list index out of range
